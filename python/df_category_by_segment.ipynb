# %%
import pandas as pd

df_category_by_segment=pd.read_csv('../data/brazilian_e-commerce/category_by_segment.csv')

df_category_by_segment
# Out:
#             business_segment  \
# 0                       Baby
# 1            Beauty & Health
# 2         Books & Stationery
# 3            Car Accessories
# 4         Construction Tools
# 5   Electronics & Technology
# 6      Fashion & Accessories
# 7               Food & Drink
# 8                  Furniture
# 9              Home & Living
# 10       Household Utilities
# 11                     Music
# 12              Pet Supplies
# 13                     Sport
# 14               Supplements
# 15                      Toys
# 16                Travelling
#
#                                        category_clean
# 0      ['baby_products' 'miscellaneous' 'stationary']
# 1   ['beauty' 'fashion' 'stationary' 'home_kitchen...
# 2   ['stationary' 'toys_games' 'books_media' 'baby...
# 3   ['automotive_tools' 'home_kitchen' 'garden_out...
# 4   ['construction_tools' 'garden_outdoor' 'comput...
# 5   ['cellphone_accessories' 'computers_technology...
# ...
