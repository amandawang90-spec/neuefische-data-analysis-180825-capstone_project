# %% [markdown]
# ## read data: download states dataset from sql database

# %%
from sqlalchemy import create_engine
from sqlalchemy import text 
import pandas as pd

# %%
from dotenv import dotenv_values

config = dotenv_values()

pg_user = config['POSTGRES_USER']  
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %%
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}' #the same like version 1

engine = create_engine(url, echo=False) 

my_schema = 'team_jjat'

with engine.begin() as conn: 
    result = conn.execute(text(f'SET search_path TO {my_schema};'))

# %%
prep_states = pd.read_sql('SELECT * FROM states;', con=engine)
prep_states.head()
# Out:
#    UF     State     Capital     Region         Area  Population  \
# 0  AC      Acre  Rio Branco      North   164123.730      881935
# 1  AL   Alagoas      Maceió  Northeast    27843.295     3337357
# 2  AM  Amazonas      Manaus      North  1559168.100     4144597
# 3  AP     Amapá      Macapá      North   142470.770      845731
# 4  BA     Bahia    Salvador  Northeast   564722.600    14873064
#
#    Demographic Density  Cities count       GDP  GDP rate  Poverty  Latitude  \
# 0                 5.37            22  17201.95       0.5    0.189     -8.77
# 1               119.86           102  15653.51       0.5    0.205     -9.62
# 2                 2.66            62  22936.28       0.7    0.193     -3.47
# 3                 5.94            16  19405.11       0.6    0.128      1.41
# 4                26.34           417  17508.67       0.6    0.177    -13.29
#
#    Longitude
# 0     -70.55
# 1     -36.82
# 2     -65.10
# 3     -51.77
# 4     -41.71

# %% [markdown]
# ## Data inspection

# %%
prep_states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   UF                   27 non-null     object
#  1   State                27 non-null     object
#  2   Capital              27 non-null     object
#  3   Region               27 non-null     object
#  4   Area                 27 non-null     float64
#  5   Population           27 non-null     int64
#  6   Demographic Density  27 non-null     float64
#  7   Cities count         27 non-null     int64
#  8   GDP                  27 non-null     float64
#  9   GDP rate             27 non-null     float64
#  10  Poverty              27 non-null     float64
#  11  Latitude             27 non-null     float64
#  12  Longitude            27 non-null     float64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 2.9+ KB

# %%
prep_states.isnull().sum()
# Out:
# UF                     0
# State                  0
# Capital                0
# Region                 0
# Area                   0
# Population             0
# Demographic Density    0
# Cities count           0
# GDP                    0
# GDP rate               0
# Poverty                0
# Latitude               0
# Longitude              0
# dtype: int64

# %%
prep_states.duplicated().sum()
# Out:
# np.int64(0)

# %%
prep_states['UF'].nunique()
# Out:
# 27

# %% [markdown]
# ## Data cleaning

# %%
# Convert all column names to lowercase
prep_states.columns = prep_states.columns.str.lower()

# Verify
print(prep_states.columns)
# Out:
# Index(['uf', 'state', 'capital', 'region', 'area', 'population',
#        'demographic density', 'cities count', 'gdp', 'gdp rate', 'poverty',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
prep_states = prep_states.applymap(
    lambda x: x.lower() if isinstance(x, str) else x
)
prep_states
# Out:
# /var/folders/dy/7tw8bprs1tn0zkqfvzdxm3gc0000gn/T/ipykernel_58490/4055374266.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   prep_states = prep_states.applymap(
#     uf                state         capital       region         area  \
# 0   ac                 acre      rio branco        north   164123.730
# 1   al              alagoas          maceió    northeast    27843.295
# 2   am             amazonas          manaus        north  1559168.100
# 3   ap                amapá          macapá        north   142470.770
# 4   ba                bahia        salvador    northeast   564722.600
# 5   ce                ceará       fortaleza    northeast   148894.750
# 6   df     distrito federal        brasília  center-west     5760.783
# 7   es       espírito santo         vitória    southeast    46074.445
# 8   go                goiás         goiânia  center-west   340125.720
# 9   ma             maranhão        são luís    northeast   329642.160
# 10  mg         minas gerais  belo horizonte    southeast   586521.100
# 11  ms   mato grosso do sul    campo grande  center-west   357145.530
# 12  mt          mato grosso          cuiabá  center-west   903207.000
# 13  pa                 pará           belém        north  1245759.200
# 14  pb              paraíba     joão pessoa    northeast    56467.240
# 15  pe           pernambuco          recife    northeast    98068.020
# 16  pi                piauí        teresina    northeast   251616.830
# 17  pr               paraná        curitiba        south   199305.230
# 18  rj       rio de janeiro  rio de janeiro    southeast    43750.420
# 19  rn  rio grande do norte           natal    northeast    52809.600
# 20  ro             rondônia     porto velho        north   237765.230
# 21  rr              roraima       boa vista        north   224273.830
# 22  rs    rio grande do sul    porto alegre        south   281707.160
# 23  sc       santa catarina   florianópolis        south    95730.920
# 24  se              sergipe         aracaju    northeast    21926.908
# 25  sp            são paulo       são paulo    southeast   248219.480
# 26  to            tocantins          palmas        north   277720.400
#
#     population  demographic density  cities count       gdp  gdp rate  \
# 0       881935                 5.37            22  17201.95       0.5
# 1      3337357               119.86           102  15653.51       0.5
# 2      4144597                 2.66            62  22936.28       0.7
# 3       845731                 5.94            16  19405.11       0.6
# 4     14873064                26.34           417  17508.67       0.6
# 5      9132078                61.33           184  16394.99       0.5
# 6      3015268               523.41             1  80502.47       2.5
# 7      4018650                87.22            78  28222.56       0.9
# 8      7018354                20.63           246  28308.77       0.9
# 9      7075181                21.46           217  12788.75       0.4
# 10    21168791                36.09           853  27282.75       0.9
# 11     2778986                 7.78            79  35520.45       1.1
# 12     3484466                 3.86           141  37914.00       1.2
# 13     8602865                 6.91           144  18549.33       0.6
# 14     4018127                71.16           223  15497.67       0.5
# 15     9557071                97.45           185  19164.52       0.6
# 16     3273227                13.01           224  14089.78       0.4
# 17    11433957                57.37           399  37221.00       1.2
# 18    17264943               394.62            92  40155.76       1.3
# 19     3506853                66.41           167  18333.19       0.6
# 20     1777225                 7.47            52  24092.81       0.8
# 21      605761                 2.70            15  23158.06       0.7
# 22    11377239                40.39           497  37371.27       1.2
# 23     7164788                74.84           295  39592.28       1.2
# 24     2298696               104.83            75  17789.21       0.6
# 25    45919049               184.99           645  47008.77       1.5
# 26     1572866                 5.66           139  21998.34       0.7
#
#     poverty  latitude  longitude
# 0     0.189     -8.77     -70.55
# 1     0.205     -9.62     -36.82
# 2     0.193     -3.47     -65.10
# 3     0.128      1.41     -51.77
# 4     0.177    -13.29     -41.71
# 5     0.184     -5.20     -39.53
# 6     0.019    -15.83     -47.86
# 7     0.043    -19.19     -40.34
# 8     0.037    -15.98     -49.86
# 9     0.263     -5.42     -45.44
# 10    0.047    -18.10     -44.38
# 11    0.050    -20.51     -54.54
# 12    0.059    -12.64     -55.42
# 13    0.192     -3.79     -52.48
# 14    0.163     -7.28     -36.72
# 15    0.161     -8.38     -37.86
# 16    0.216     -6.60     -42.28
# 17    0.030    -24.89     -51.55
# 18    0.039    -22.25     -42.66
# 19    0.130     -5.81     -36.59
# 20    0.079    -10.83     -63.34
# 21    0.179      1.99     -61.33
# 22    0.029    -30.17     -53.50
# 23    0.017    -27.45     -50.95
# 24    0.153    -10.57     -37.45
# 25    0.027    -22.19     -48.79
# 26    0.119     -9.46     -48.26

# %%
prep_states.groupby('region')['state'].unique()
# Out:
# region
# center-west    [distrito federal, goiás, mato grosso do sul, ...
# north          [acre, amazonas, amapá, pará, rondônia, roraim...
# northeast      [alagoas, bahia, ceará, maranhão, paraíba, per...
# south                [paraná, rio grande do sul, santa catarina]
# southeast      [espírito santo, minas gerais, rio de janeiro,...
# Name: state, dtype: object

# %%
prep_states= prep_states.sort_values("region", ascending=True)
prep_states
# Out:
#     uf                state         capital       region         area  \
# 12  mt          mato grosso          cuiabá  center-west   903207.000
# 11  ms   mato grosso do sul    campo grande  center-west   357145.530
# 8   go                goiás         goiânia  center-west   340125.720
# 6   df     distrito federal        brasília  center-west     5760.783
# 0   ac                 acre      rio branco        north   164123.730
# 21  rr              roraima       boa vista        north   224273.830
# 20  ro             rondônia     porto velho        north   237765.230
# 13  pa                 pará           belém        north  1245759.200
# 26  to            tocantins          palmas        north   277720.400
# 2   am             amazonas          manaus        north  1559168.100
# 3   ap                amapá          macapá        north   142470.770
# 24  se              sergipe         aracaju    northeast    21926.908
# 1   al              alagoas          maceió    northeast    27843.295
# 19  rn  rio grande do norte           natal    northeast    52809.600
# 16  pi                piauí        teresina    northeast   251616.830
# 5   ce                ceará       fortaleza    northeast   148894.750
# 14  pb              paraíba     joão pessoa    northeast    56467.240
# 4   ba                bahia        salvador    northeast   564722.600
# 9   ma             maranhão        são luís    northeast   329642.160
# 15  pe           pernambuco          recife    northeast    98068.020
# 22  rs    rio grande do sul    porto alegre        south   281707.160
# 23  sc       santa catarina   florianópolis        south    95730.920
# 17  pr               paraná        curitiba        south   199305.230
# 7   es       espírito santo         vitória    southeast    46074.445
# 18  rj       rio de janeiro  rio de janeiro    southeast    43750.420
# 25  sp            são paulo       são paulo    southeast   248219.480
# 10  mg         minas gerais  belo horizonte    southeast   586521.100
#
#     population  demographic density  cities count       gdp  gdp rate  \
# 12     3484466                 3.86           141  37914.00       1.2
# 11     2778986                 7.78            79  35520.45       1.1
# 8      7018354                20.63           246  28308.77       0.9
# 6      3015268               523.41             1  80502.47       2.5
# 0       881935                 5.37            22  17201.95       0.5
# 21      605761                 2.70            15  23158.06       0.7
# 20     1777225                 7.47            52  24092.81       0.8
# 13     8602865                 6.91           144  18549.33       0.6
# 26     1572866                 5.66           139  21998.34       0.7
# 2      4144597                 2.66            62  22936.28       0.7
# 3       845731                 5.94            16  19405.11       0.6
# 24     2298696               104.83            75  17789.21       0.6
# 1      3337357               119.86           102  15653.51       0.5
# 19     3506853                66.41           167  18333.19       0.6
# 16     3273227                13.01           224  14089.78       0.4
# 5      9132078                61.33           184  16394.99       0.5
# 14     4018127                71.16           223  15497.67       0.5
# 4     14873064                26.34           417  17508.67       0.6
# 9      7075181                21.46           217  12788.75       0.4
# 15     9557071                97.45           185  19164.52       0.6
# 22    11377239                40.39           497  37371.27       1.2
# 23     7164788                74.84           295  39592.28       1.2
# 17    11433957                57.37           399  37221.00       1.2
# 7      4018650                87.22            78  28222.56       0.9
# 18    17264943               394.62            92  40155.76       1.3
# 25    45919049               184.99           645  47008.77       1.5
# 10    21168791                36.09           853  27282.75       0.9
#
#     poverty  latitude  longitude
# 12    0.059    -12.64     -55.42
# 11    0.050    -20.51     -54.54
# 8     0.037    -15.98     -49.86
# 6     0.019    -15.83     -47.86
# 0     0.189     -8.77     -70.55
# 21    0.179      1.99     -61.33
# 20    0.079    -10.83     -63.34
# 13    0.192     -3.79     -52.48
# 26    0.119     -9.46     -48.26
# 2     0.193     -3.47     -65.10
# 3     0.128      1.41     -51.77
# 24    0.153    -10.57     -37.45
# 1     0.205     -9.62     -36.82
# 19    0.130     -5.81     -36.59
# 16    0.216     -6.60     -42.28
# 5     0.184     -5.20     -39.53
# 14    0.163     -7.28     -36.72
# 4     0.177    -13.29     -41.71
# 9     0.263     -5.42     -45.44
# 15    0.161     -8.38     -37.86
# 22    0.029    -30.17     -53.50
# 23    0.017    -27.45     -50.95
# 17    0.030    -24.89     -51.55
# 7     0.043    -19.19     -40.34
# 18    0.039    -22.25     -42.66
# 25    0.027    -22.19     -48.79
# 10    0.047    -18.10     -44.38

# %% [markdown]
# ## Save data
