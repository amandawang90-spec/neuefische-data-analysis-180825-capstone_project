# %%
from sqlalchemy import create_engine
from sqlalchemy import text 
import pandas as pd

# %%
from dotenv import dotenv_values

config = dotenv_values()

pg_user = config['POSTGRES_USER']  
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %%
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}' #the same like version 1

engine = create_engine(url, echo=False) 

my_schema = 'team_jjat'

with engine.begin() as conn: 
    result = conn.execute(text(f'SET search_path TO {my_schema};'))

# %%
prep_category_name_translation = pd.read_sql('SELECT * FROM prep_category_name_translation;', con=engine)
prep_category_name_translation.head()
# Out:
#   product_subcategory_name product_subcategory_name_english  \
# 0             beleza_saude                    health_beauty
# 1   informatica_acessorios            computers_accessories
# 2               automotivo                             auto
# 3          cama_mesa_banho                   bed_bath_table
# 4         moveis_decoracao                  furniture_decor
#
#        product_category
# 0                beauty
# 1  computers_technology
# 2      automotive_tools
# 3          home_kitchen
# 4             furniture

# %%
prep_category_name_translation.to_csv('prep_category_name_translation.csv', index=False)

# %%
prep_gdp = pd.read_sql('SELECT * FROM prep_gdp;', con=engine)
prep_gdp.head()
# Out:
#   state_code        state_name       GDP  Population  total_customers  \
# 0         SP         São Paulo  47008.77    45919049            41746
# 1         RJ    Rio de Janeiro  40155.76    17264943            12852
# 2         DF  Distrito Federal  80502.47     3015268             2140
# 3         MG      Minas Gerais  27282.75    21168791            11635
# 4         SC    Santa Catarina  39592.28     7164788             3637
#
#    customers_per_million  gdp_per_capita       region
# 0             909.121615     1023.731339    southeast
# 1             744.398635     2325.855447    southeast
# 2             709.721325    26698.279805  center-west
# 3             549.629877     1288.819470    southeast
# 4             507.621440     5525.952931        south

# %%
prep_gdp.to_csv('prep_gdp.csv', index=False)

# %%
prep_order_items = pd.read_sql('SELECT * FROM prep_order_items;', con=engine)
prep_order_items.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#    order_item_id                         seller_id  shipping_limit_date  \
# 0              1  48436dade18ac8b2bce089ec2a041202  2017-09-19 09:45:35
# 1              1  dd7ddc04e1b6c2c614352b383efe2d36  2017-05-03 11:05:13
# 2              1  5b51032eddd242adc84c38acab88f23d  2018-01-18 14:48:30
# 3              1  9d7a1d34a5052409006425275ba1c2b4  2018-08-15 10:10:18
# 4              1  df560393f3a51e74553ab94004ba5c87  2017-02-13 13:57:51
#
#     price  freight_value
# 0   58.90          13.29
# 1  239.90          19.93
# 2  199.00          17.87
# 3   12.99          12.79
# 4  199.90          18.14

# %%
prep_order_items.to_csv('prep_order_items.csv', index=False)

# %%
prep_products = pd.read_sql('SELECT * FROM prep_products;', con=engine)
prep_products.head()
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 44.0
# 2  96bd76ec8810374ed1b65e291975717f                 46.0
# 3  cef67bcfe19066a932b7673e239eb23d                 27.0
# 4  9dc1a7de274444849c219cff195d0b71                 37.0
#
#    product_description_lenght  product_photos_qty product_subcategory_name  \
# 0                       287.0                 1.0               perfumaria
# 1                       276.0                 1.0                    artes
# 2                       250.0                 1.0            esporte_lazer
# 3                       261.0                 1.0                    bebes
# 4                       402.0                 4.0    utilidades_domesticas
#
#   product_subcategory_name_english product_category
# 0                        perfumery           beauty
# 1                              art      arts_crafts
# 2                   sports_leisure          fashion
# 3                             baby    baby_products
# 4                       housewares     home_kitchen

# %%
prep_products.to_csv('prep_products.csv', index=False)

# %%
prep_review = pd.read_sql('SELECT * FROM prep_review;', con=engine)
prep_review.head()
# Out:
#                           review_id                          order_id  \
# 0  97ca439bc427b48bc1cd7177abe71365  00010242fe8c5a6d1ba2dd792cb16214
# 1  7b07bacd811c4117b742569b04ce3580  00018f77f2f0320c557190d7a144bdd3
# 2  0c5b33dea94867d1ac402749e5438e8b  000229ec398224ef6ca0657da4fc703e
# 3  f4028d019cb58564807486a6aaf33817  00024acbcdf0a6daa1e931b038114c75
# 4  940144190dcba6351888cafa43f3a3a5  00042b26cf59d7ce69dfabb4e55b4fd9
#
#    review_score review_comment_title  \
# 0             5
# 1             4
# 2             5
# 3             4
# 4             5
#
#                               review_comment_message review_creation_date  \
# 0     Perfeito, produto entregue antes do combinado.  2017-09-21 00:00:00
# 1                                                     2017-05-13 00:00:00
# 2  Chegou antes do prazo previsto e o produto sur...  2018-01-23 00:00:00
# 3                                                     2018-08-15 00:00:00
# 4            Gostei pois veio no prazo determinado .  2017-03-02 00:00:00
#
#   review_answer_timestamp                                       clean_review  \
# 0     2017-09-22 10:57:03     perfeito, produto entregue antes do combinado.
# 1     2017-05-15 11:34:13
# 2     2018-01-23 16:06:31  chegou antes do prazo previsto e o produto sur...
# 3     2018-08-15 16:39:01
# 4     2017-03-03 10:54:59            gostei pois veio no prazo determinado .
#
#    category
# 0      both
# 1      none
# 2      both
# 3      none
# 4  delivery

# %%
prep_review.to_csv('prep_review.csv', index=False)

# %%
prep_seller = pd.read_sql('SELECT * FROM prep_seller', con=engine)
prep_seller.head()
# Out:
#                           seller_id seller_zip_code_prefix  seller_city  \
# 0  00065220becb8785e2cf78355eb9bf68                   None         None
# 1  0015a82c2db000af6aaaf3ae2ecb0532                  09080  santo andre
# 2  001cca7ae9ae17fb1caed9dfb1094831                  29156    cariacica
# 3  001e6ad469a905060d959994f1b41e4f                  24754  sao goncalo
# 4  002100f778ceb8431b7a1020ff7ab48f                  14405       franca
#
#   seller_state            won_date business_segment_old      lead_type  \
# 0         None 2018-07-10 11:34:50          handcrafted  online_medium
# 1           SP                 NaT                 None           None
# 2           ES                 NaT                 None           None
# 3           RJ                 NaT                 None           None
# 4           SP                 NaT                 None           None
#
#    has_company  has_gtin business_type business_segment  \
# 0        False     False      reseller    Home & Living
# 1         True      True          None             None
# 2         True      True          None             None
# 3         True      True          None             None
# 4         True      True          None             None
#
#       business_segment_pred business_segment_incl_pred
# 0                      None              Home & Living
# 1  Electronics & Technology   Electronics & Technology
# 2        Construction Tools         Construction Tools
# 3                     Sport                      Sport
# 4             Home & Living              Home & Living

# %%
prep_seller.to_csv('prep_seller.csv', index=False)

# %%
prep_temperature= pd.read_sql('SELECT * FROM prep_temperature', con=engine)
prep_temperature.head()
# Out:
#         station_name  station_id  latitude  longitude  altitude measure_date  \
# 0  ALTO DA BOA VISTA       83007     -23.0      -43.3     347.1   2016-01-01
# 1  ALTO DA BOA VISTA       83007     -23.0      -43.3     347.1   2016-01-02
# 2  ALTO DA BOA VISTA       83007     -23.0      -43.3     347.1   2016-01-03
# 3  ALTO DA BOA VISTA       83007     -23.0      -43.3     347.1   2016-01-04
# 4  ALTO DA BOA VISTA       83007     -23.0      -43.3     347.1   2016-01-05
#
#    max_temperature  min_temperature
# 0             33.0             24.2
# 1             26.0             21.3
# 2             23.9             21.3
# 3             25.2             20.2
# 4             26.1             18.5

# %%
prep_temperature.to_csv('prep_seller.csv', index=False)

# %%
mart_basket_analysis= pd.read_sql('SELECT * FROM mart_basket_analysis', con=engine)
mart_basket_analysis.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#    order_item_id                         seller_id   price  freight_value  \
# 0              1  48436dade18ac8b2bce089ec2a041202   58.90          13.29
# 1              1  dd7ddc04e1b6c2c614352b383efe2d36  239.90          19.93
# 2              1  5b51032eddd242adc84c38acab88f23d  199.00          17.87
# 3              1  9d7a1d34a5052409006425275ba1c2b4   12.99          12.79
# 4              1  df560393f3a51e74553ab94004ba5c87  199.90          18.14
#
#   product_category product_subcategory_name_english  \
# 0    miscellaneous                       cool_stuff
# 1     pet_supplies                         pet_shop
# 2        furniture                  furniture_decor
# 3           beauty                        perfumery
# 4   garden_outdoor                     garden_tools
#
#                         customer_id                customer_unique_id  \
# 0  3ce436f183e68e07877b285a838db11a  871766c5855e863f6eccc05f988b23cb
# 1  f6dd3ec061db4e3987629fe6b26e5cce  eb28e67c4c0b83846050ddfb8a35d051
# 2  6489ae5e4333f3693df5ad4372dab6d3  3818d81c6709e39d06b2738a8d3a2474
# 3  d4eb9395c8c0431ee92fce09860c5a06  af861d436cfc08b2c2ddefd0ba074622
# 4  58dbd0b2d70206bf40e62cd34e84d795  64b576fb70d441e8f1b2d7d446e483c5
#
#   customer_region order_purchase_timestamp
# 0       southeast      2017-09-13 08:59:02
# 1       southeast      2017-04-26 10:53:06
# 2       southeast      2018-01-14 14:33:31
# 3       southeast      2018-08-08 10:00:35
# 4       southeast      2017-02-04 13:57:51

# %%
mart_basket_analysis.to_csv('mart_basket_analysis.csv', index=False)

# %%
mart_customer_count_by_seller = pd.read_sql('SELECT * FROM mart_customer_count_by_seller;', con=engine)
mart_customer_count_by_seller.head()
# Out:
#                           seller_id  count_customers
# 0  6560211a19b47992c3666cc44a7e94c0             1817
# 1  4a3ca9315b744ce9f8e9374361493884             1790
# 2  cc419e0650a3c5ba77189a1882b7556a             1648
# 3  1f50f920176fa81dab994f9023523100             1387
# 4  955fee9216a65b617aa5c0531780ce60             1281

# %%
mart_customer_count_by_seller.to_csv('mart_customer_count_by_seller.csv', index=False)

# %%
mart_seller_fulfillment_scorecard = pd.read_sql('SELECT * FROM mart_seller_fulfillment_scorecard;', con=engine)
mart_seller_fulfillment_scorecard.head()
# Out:
#                            order_id order_status order_purchase_timestamp  \
# 0  2e7a8482f6fb09756ca50c10d7bfc047      shipped      2016-09-04 21:15:19
# 1  2e7a8482f6fb09756ca50c10d7bfc047      shipped      2016-09-04 21:15:19
# 2  e5fa5a7210941f7d56d0208e4e071d35     canceled      2016-09-05 00:15:34
# 3  809a282bbd5dbcabb6f2f724fca862ec     canceled      2016-09-13 15:24:19
# 4  bfbd0f9bdef84302105ad712db648a6c    delivered      2016-09-15 12:16:38
#
#     order_approved_at shipping_limit_date order_delivered_carrier_date  \
# 0 2016-10-07 13:18:03 2016-10-26 18:25:19          2016-10-18 13:14:51
# 1 2016-10-07 13:18:03 2016-10-26 18:25:19          2016-10-18 13:14:51
# 2 2016-10-07 13:17:15 2016-09-19 00:15:34                          NaT
# 3 2016-10-07 13:16:46                 NaT                          NaT
# 4 2016-09-15 12:16:38 2016-09-19 23:11:33          2016-11-07 17:11:53
#
#   order_delivered_customer_date order_estimated_delivery_date  price  \
# 0                           NaT                    2016-10-20  39.99
# 1                           NaT                    2016-10-20  32.90
# 2                           NaT                    2016-10-28  59.50
# 3                           NaT                    2016-09-30    NaN
# 4           2016-11-09 07:47:38                    2016-10-04  44.99
#
#    freight_value                       customer_id  \
# 0          31.67  08c5351a6aca1c1589a38f244edeee9d
# 1          31.67  08c5351a6aca1c1589a38f244edeee9d
# 2          15.56  683c54fc24d40ee9f8a6fc179fd9856c
# 3            NaN  622e13439d6b5a0b486c435618b2679e
# 4           2.83  86dc2ffce2dfff336de2f386a786e574
#
#                           seller_id                        product_id  \
# 0  1554a68530182680ad5c8b042c3ab563  c1488892604e4ba5cff5b4eb4d595400
# 1  1554a68530182680ad5c8b042c3ab563  f293394c72c9b5fafd7023301fc21fc2
# 2  a425f92c199eb576938df686728acd20  f3c2d01a84c947b078e32bbef0718962
# 3                              None                              None
# 4  ecccfa2bb93b34a3bf033cc5d1dcdc69  5a6b04657a4c5ee34285d1e4619a96b4
#
#   business_segment_old business_segment business_segment_pred  \
# 0                 None             None         Home & Living
# 1                 None             None         Home & Living
# 2                 None             None         Home & Living
# 3                 None             None                  None
# 4                 None             None       Beauty & Health
#
#   business_segment_incl_pred
# 0              Home & Living
# 1              Home & Living
# 2              Home & Living
# 3                       None
# 4            Beauty & Health

# %%
mart_seller_fulfillment_scorecard.to_csv('mart_seller_fulfillment_scorecard.csv', index=False)

# %%
mart_customer_transactions = pd.read_sql('SELECT * FROM mart_seller_fulfillment_scorecard;', con=engine)
mart_customer_transactions.head()
